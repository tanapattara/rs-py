# %%
import pandas as pd

ratingsdf = pd.read_csv("data/rating_pop.csv", sep='|')
venuedf = pd.read_csv("data/venue_metadata.csv", sep='|')
categorydf = pd.read_csv("data/categorydf.csv", sep='|')
simdf = pd.read_csv("data/simdf.csv", sep='|')
category = categorydf.category.unique()
simdf = simdf.sort_values(by=['s'], ascending=False)
simdf
# Out:
#            u       v         s
# 6881  1567.0  4752.0  5.570840
# 1139   550.0  3209.0  5.328965
# 3391  5843.0  5831.0  1.866019
# 6332  6886.0  6442.0  1.640727
# 1016   521.0  1738.0  1.473557
# ...      ...     ...       ...
# 3989  2657.0  5298.0 -0.617468
# 1966  7987.0  7978.0 -1.023617
# 3428    69.0  2734.0 -1.141129
# 6646  2135.0  3946.0 -1.683443
# 6846  7870.0  4477.0 -3.462896
#
# [7537 rows x 3 columns]
